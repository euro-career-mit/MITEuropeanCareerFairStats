# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("~/Downloads/Typeform_Responses_2024.csv", low_memory=False)
print("Read the .CSV file.")
# Out:
# Read the .CSV file.

# %%
df.size
# Out:
# 309120

# %%
df.shape
# Out:
# (3360, 92)

# %%
set([])
# Out:
# set()

# %% [markdown]
# # Field of study

# %%
# In this list, the last items has the priority to override
fieldRanking = ['marketing', 'industrial', 'supply chain', 'law', 'chemical', 'finance', 'economic',
     'political', 'business', 'management', 'mba', 'civil', 'physics', 'mechanical', 'material', 'aerospace',
     'electrical', 'electronic', 'computer', 'bio', 'analytics', 'data', 'artificial', 'machine learning']

# %%
# Let us see the possible (unique) values as a set, in the given dataset

# fieldString = "Major"
fieldString = "What is your major?"

try:
    set(df[fieldString])
except:
    fieldString = "Major" # capital "Study"
    set(df[fieldString])

# %%
names = df[fieldString].unique()[:-1]
# names[0].find('Computer Sciences')
names_cs = [names[i] for i in range(len(names)) if names[i].find('Computer Sciences') != -1]
names_eng = [names[i] for i in range(len(names)) if names[i].find('Engineering') != -1]

# %%
names_cs
# for i in range(len(names)):
#     if names[i].find('Computer Science') != -1:
#         print(i)
# Out:
# ['Computer Sciences, Computer Science',
#  'Computer Sciences, Data Analytics',
#  'Computer Sciences, Artificial Intelligence (AI) & Machine Learning (ML)',
#  'Computer Sciences, Computer Programming',
#  'Computer Sciences, Data Science',
#  'Computer Sciences, Software Development',
#  'Computer Sciences, Information Systems/Technology Management',
#  'Computer Sciences, Computer Systems Analysis',
#  'Computer Sciences, Web Design/Development',
#  'Computer Sciences, Information Sciences & Systems',
#  'Computer Sciences, Combinatorics & Optimization',
#  'Computer Sciences, Information Technology',
#  'Computer Sciences, Management & Information Systems',
#  'Computer Sciences, Digital Media & Design',
#  'Computer Sciences, Gaming & Simulation Development',
#  'Computer Sciences, Network Security & Cyber Intelligence',
#  'Computer Sciences, Database Management',
#  'Computer Sciences, Hardware Technology',
#  'Computer Sciences, Computer Networking/Administration']

# %%
mostRelevantField
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 mostRelevantField
#
# NameError: name 'mostRelevantField' is not defined

# %%
#create new column
mostRelevantField = ["Other"]*len(df)

# for each candidate (row)
for i in range(len(df)): 
    
    # get candidate's fields of study
    fieldsOfCandidate = df.loc[i, fieldString]
    
    if isinstance(fieldsOfCandidate, str):
        # make lowercase if it is a string! 
        fieldsOfCandidate = fieldsOfCandidate.lower()
        
        # for each field (column) in the ranking list
        for wantedColumn in fieldRanking: 

            if wantedColumn in fieldsOfCandidate:
                mostRelevantField[i] = wantedColumn

# %% [markdown]
# ### For similar field names, use a single (unique) name

# %%
fieldSynonyms = {
    "artificial": "AI",
    "machine learning": "AI",
    
    "data": "Data Science",
    "analytics": "Data Science",
    
    "bio": "Biology",
    
    "computer": "CS",
    
    "aerospace": "Aero",
    
    "material": "Materials",
    
    "mechanical": "Mechanical Eng",
    
    "electrical": "Electrical Eng",
    "electronic": "Electrical Eng",
    
    "physics": "Physics",
    
    "civil": "Civil Eng",
    
    "business": "Business",
    "mba": "Business",
    "management": "Business",
    
    "political": "Policital Sci",
    
    "economic": "Finance",
    "finance": "Finance",
    
    "chemical": "Chemistry",
    
    "supply chain": "Industrial Eng",
    "industrial": "Industrial Eng",
    
    "law": "Law",
    
    "marketing": "Marketing",
    
}

# %%
replacementCount = 0

# for each candidate
for i in range(len(mostRelevantField)):

    # if the candidate's field is in fieldSynonyms
    if mostRelevantField[i] in fieldSynonyms:

        # replace it with the more common field name
        mostRelevantField[i] = fieldSynonyms[mostRelevantField[i]]
        
        replacementCount = replacementCount+1
      
print(str(replacementCount) + " fields have been renamed!")
# Out:
# 2539 fields have been renamed!

# %%
df["mostRelevantField"] = mostRelevantField

# %% [markdown]
# # University name

# %%
university_q = "What school do you attend?"

# List unique university names      
set(df["What school do you attend?"])
# Out:
# {'Boston College',
#  'Boston University',
#  'Dartmouth',
#  'Harvard',
#  'Hult Business',
#  'MIT',
#  'NYU',
#  'Northeastern',
#  'Tufts',
#  'Wellesley',
#  nan}

# %%
# In this list, the last items has the priority to override
uniRanking = ['university of connecticut', 'worcester polytechnic', 'wpi',
              'wellesley college', 'university of massachusetts boston', 'dartmouth college', 'dartmouth university',
              'brandeis university', 'university of massachusetts amherst', 'boston college', 'tufts university',
              'new york university', 'nyu',
              'hult international', 'hult business', 'boston university', 'northeastern university', 'northeastern',
              'harvard college', 'harvard university',
              'massachusetts institute of technology', 'mit', 'smith college']

# %%
#create new column
mostRelevantUni = ["Other"]*len(df)

# for each candidate (row)
for i in range(len(df)): 
    
    # get candidate's fields of study
    unisOfCandidate = df.loc[i, "What school do you attend?"]
    
    if isinstance(unisOfCandidate, str):
        # make lowercase if it is a string! 
        unisOfCandidate = unisOfCandidate.lower()
        
        # for each field (column) in the ranking list
        for wantedUniversity in uniRanking: 

            if wantedUniversity in unisOfCandidate:
                mostRelevantUni[i] = wantedUniversity

# %% [markdown]
# ### For equivalent university names, use a single (unique) name

# %%
# In this list, the last items has the priority to override
# uniRanking = ['university of connecticut', 'worcester polytechnic',
#               'wellesley college', 'university of massachusetts boston', 'dartmouth college', 'dartmouth university',
#               'brandeis university', 'university of massachusetts amherst', 'boston college', 'tufts university',
#               'new york university', 'nyu',
#               'hult international', 'hult business', 'boston university', 'northeastern university', 'northeastern',
#               'harvard college', 'harvard university',
#               'massachusetts institute of technology', 'mit', 'smith college']


uniSynonyms = {
    "massachusetts institute of technology": "MIT",
    "mit": "MIT",
    
    "harvard college": "Harvard",
    "harvard university": "Harvard",
    
    "hult international": "Hult Business",
    "hult business": "Hult Business",
    
    "northeastern university": "Northeastern",
    "northeastern": "Northeastern",
    
    "boston university": "BU",
    
    "tufts university": "Tufts",
    
    "dartmouth university": "Dartmouth",
    "dartmouth college": "Dartmouth",
    
    "new york university": "NYU",
    "nyu": "NYU",
        
    "boston college": "Boston College",
    
    "brandeis university": "Brandeis",
    "wellesley": "Wellesley",
    "wellesley college": "Wellesley",
    
    "university of massachusetts amherst": "UMass Amherst",
    
    "university of massachusetts boston": "UMass Boston",
    
    
    "worcester polytechnic": "WPI",
    "wpi": "WPI",
    
    "university of connecticut": "UConn",
    
    "smith college": "Smith"
    
}

# %%
replacementCount = 0

# for each candidate
for i in range(len(mostRelevantUni)):

    # if the candidate's field is in fieldSynonyms
    if mostRelevantUni[i] in uniSynonyms:

        # replace it with the more common field name
        mostRelevantUni[i] = uniSynonyms[mostRelevantUni[i]]
        
        replacementCount = replacementCount+1
      
print(str(replacementCount) + " university names have been renamed!")
# Out:
# 2328 university names have been renamed!

# %%
df["mostRelevantUni"] = mostRelevantUni

# %%
#Show the result
pd.set_option('display.min_rows', 6)

df
# Out:
#                                      #       What is your email?  \
# 0     4exrzrhgk95itv0xk4exrz6wc7qpkb1l          pkorfuzi@wpi.edu
# 1     ecvt1ow963petev4ecnslf6izfb8nb1t  hrishireddy456@gmail.com
# 2     n7vbdcb9kcznyca9n7vbcqjzu9cbupe2   kendall_clark@brown.edu
# ...                                ...                       ...
# 3357  vm3krofi6npvtxa1281vm3cbzwdg2zgl          victorqi@mit.edu
# 3358                               NaN                       NaN
# 3359                               NaN                       NaN
#
#      What is your first name? What is your last name?  \
# 0                       Peter                 Korfuzi
# 1            Hrishikesh Reddy                Komandla
# 2                     Kendall                   Clark
# ...                       ...                     ...
# 3357                   Victor                     Qin
# 3358                      NaN                     NaN
# 3359                      NaN                     NaN
#
#      What school do you attend?                            Other  \
# 0                           NaN  Worcester Polytechnic Institute
# 1                  Northeastern                              NaN
# 2                           NaN                            Brown
# ...                         ...                              ...
# 3357                        MIT                              NaN
# 3358                        NaN                              NaN
# 3359                        NaN                              NaN
#
#      What degree program are you currently pursuing? Other.1  \
# 0                                      Undergraduate     NaN
# 1                                           Master's     NaN
# 2                                                PhD     NaN
# ...                                              ...     ...
# 3357                                             PhD     NaN
# 3358                                             NaN     NaN
# 3359                                             NaN     NaN
#
#                            What is your major? What is your (other) major?  \
# 0           Engineering, Aerospace Engineering                         NaN
# 1     Business & Commerce, Marketing Analytics                         NaN
# 2              Liberal Arts, Political Science                         NaN
# ...                                        ...                         ...
# 3357        Engineering, Aeronautical Sciences                         NaN
# 3358                                       NaN                         NaN
# 3359                                       NaN                         NaN
#
#       ...             Upload your resume here (recommended): utm_source  \
# 0     ...  https://api.typeform.com/responses/files/0c2b5...        NaN
# 1     ...  https://api.typeform.com/responses/files/476dc...  insta.ads
# 2     ...                                                NaN        NaN
# ...   ...                                                ...        ...
# 3357  ...                                                NaN        NaN
# 3358  ...                                                NaN        NaN
# 3359  ...                                                NaN        NaN
#
#      Response Type     Start Date (UTC) Stage Date (UTC)    Submit Date (UTC)  \
# 0        completed   2024-03-05 3:11:37              NaN   2024-03-05 3:16:30
# 1        completed  2024-03-04 23:24:59              NaN  2024-03-04 23:32:22
# 2        completed  2024-03-04 20:07:01              NaN  2024-03-04 20:09:17
# ...            ...                  ...              ...                  ...
# 3357     completed  2023-11-09 14:56:53              NaN  2023-11-09 14:57:46
# 3358           NaN                  NaN              NaN                  NaN
# 3359           NaN                  NaN              NaN                  NaN
#
#       Network ID Tags mostRelevantField mostRelevantUni
# 0     27ca25c2e0  NaN              Aero           Other
# 1     f0d0785eb1  NaN      Data Science    Northeastern
# 2     49ab3f2f37  NaN     Policital Sci           Other
# ...          ...  ...               ...             ...
# 3357  2ab733037f  NaN             Other             MIT
# 3358         NaN  NaN             Other           Other
# 3359         NaN  NaN             Other           Other
#
# [3360 rows x 94 columns]

# %% [markdown]
# # Highest degree

# %%
degreeRanking = ['high school', 'undergraduate','bachelor',
     'master', 'mba', 'phd', 'doctorate',
     'postdoc',  'post doc', 'md']

# %%
# List unique values
degreeFieldString = "Current degree"

try:
    set(df[degreeFieldString])
except:
    degreeFieldString = "Current Degree"
    set(df[degreeFieldString])

# %%
# List unique degree names
set(df[degreeFieldString])
# Out:
# {'Associate Degree',
#  'Bachelor',
#  'High School Diploma',
#  'Ingénieur - BAC+4',
#  'MBA',
#  'Master',
#  'PhD',
#  nan}

# %%
#create new column
highestDegree = ["Other"]*len(df)

# for each candidate (row)
for i in range(len(df)): 
    
    # get candidate's fields of study
    degreeOfCandidate = df.loc[i, degreeFieldString]
    
    if isinstance(degreeOfCandidate, str):
        # make lowercase if it is a string! 
        degreeOfCandidate = degreeOfCandidate.lower()
        
        # for each field (column) in the ranking list
        for preferredDegree in degreeRanking: 

            if preferredDegree in degreeOfCandidate:
                highestDegree[i] = preferredDegree

# %%
degreeSynonyms = {
    "high school": "High school",
    
    "undergraduate": "Bachelors",
    "bachelor": "Bachelors",
    
    "master": "Masters",
    
    "mba": "MBA",
    
    'phd': "PhD",
    'doctorate': "PhD",
    
    "postdoc": "Postdoc",
    "post doc": "Postdoc",
    
    'md': "MD"
}

# %%
replacementCount = 0

# for each candidate
for i in range(len(highestDegree)):

    # if the candidate's field is in degreeSynonyms
    if highestDegree[i] in degreeSynonyms:

        # replace it with the more common name
        highestDegree[i] = degreeSynonyms[highestDegree[i]]
        
        replacementCount = replacementCount+1
      
print(str(replacementCount) + " degree names have been renamed!")
# Out:
# 1234 degree names have been renamed!

# %%
df["highestDegree"] = highestDegree

# %%
#Show the result
pd.set_option('display.min_rows', 6)

df
# Out:
#      Created at  User ID First Name  Last Name                         Email  \
# 0     1/28/2022    16422    Paulina    Szyzdek  paulinaannaszyzdek@gmail.com
# 1      2/6/2022    59858       Keya      Dutta             kd476@cornell.edu
# 2     2/16/2022    60336   Vittorio  Albergamo               valberg@mit.edu
# ...         ...      ...        ...        ...                           ...
# 1505  2/19/2022   158082      Kaveh     Sarraf     kavehsarraf7663@gmail.com
# 1506  2/19/2022   158092       Amir    Khazaie             733amir@gmail.com
# 1507  2/19/2022   158126    Ziningi      Myeni             myeniz@ukzn.ac.za
#
#      Desired employment                                             Cities  \
# 0         Full-time job  Zürich,Stockholm,Oslo,Copenhagen,Boston,San Fr...
# 1         Part-time Job                                                NaN
# 2         Full-time Job                                                NaN
# ...                 ...                                                ...
# 1505      Full-time Job                                                NaN
# 1506      Full-time Job                                                NaN
# 1507    Working student                                                NaN
#
#      Willing to relocate Next employment from           Working experience  \
# 0                    Yes              02/2022                    5-8 years
# 1                    NaN              06/2024  No full-time experience yet
# 2                    NaN              04/2022                    5-8 years
# ...                  ...                  ...                          ...
# 1505                 NaN              03/2022                    3-5 years
# 1506                 NaN              04/2022                    5-8 years
# 1507                 Yes              07/2022                     8+ years
#
#       ...       City        Country                Languages  \
# 0     ...  Cambridge  United States           Polish,English
# 1     ...        NaN            NaN                  English
# 2     ...     Boston  United States  Spanish,Italian,English
# ...   ...        ...            ...                      ...
# 1505  ...        NaN            NaN            English,Farsi
# 1506  ...        NaN            NaN            Farsi,English
# 1507  ...        NaN            NaN                  English
#
#       Programming languages  \
# 0     No programming skills
# 1                       NaN
# 2                         R
# ...                     ...
# 1505                    NaN
# 1506                    NaN
# 1507                    NaN
#
#                                            Universities  \
# 0     University of Economics ,University of Economi...
# 1                                    Cornell University
# 2                                                   NaN
# ...                                                 ...
# 1505                                                NaN
# 1506                   Isfahan University of Technology
# 1507                                                NaN
#
#                                          Work companies  \
# 0     Chatham Financial,DigitalDX Ventures,Euroclear...
# 1                                                   NaN
# 2                 Massachusetts Institute of Technology
# ...                                                 ...
# 1505                                                NaN
# 1506                                   bahamta,Digikala
# 1507                        University of KwaZulu-Natal
#
#      Where did you hear about the Fair? mostRelevantField mostRelevantUni  \
# 0                       Other MIT Email           Finance           Other
# 1                       Other MIT Email             Other           Other
# 2                  MIT Department Email             Other           Other
# ...                                 ...               ...             ...
# 1505                          Instagram    Mechanical Eng           Other
# 1506                          Instagram                CS           Other
# 1507        Friend/Personal Connections             Other           Other
#
#       highestDegree
# 0           Masters
# 1         Bachelors
# 2             Other
# ...             ...
# 1505          Other
# 1506      Bachelors
# 1507          Other
#
# [1508 rows x 38 columns]

# %% [markdown]
# # Get rid of other columns!

# %%
columnsToStay = ['User ID',
                 'mostRelevantField',
                 'mostRelevantUni',
                 'highestDegree']

# %%
df = df[columnsToStay]

# %%
pd.set_option('display.min_rows', 10)
df
# Out:
#       User ID mostRelevantField mostRelevantUni highestDegree
# 0       16422           Finance           Other       Masters
# 1       59858             Other           Other     Bachelors
# 2       60336             Other           Other         Other
# 3       60358                CS             MIT           PhD
# 4       60512          Business             MIT       Masters
# ...       ...               ...             ...           ...
# 1503   158069           Finance             MIT       Masters
# 1504   158080           Physics             MIT     Bachelors
# 1505   158082    Mechanical Eng           Other         Other
# 1506   158092                CS           Other     Bachelors
# 1507   158126             Other           Other         Other
#
# [1508 rows x 4 columns]

# %% [markdown]
# # Make it a grouped summary list

# %%
# Calculate number of records

colums2group = ['mostRelevantUni', 'mostRelevantField', 'highestDegree']
groupedCandidateNumbers = pd.DataFrame({'count': df.groupby(colums2group).size()})

#Source: https://stackoverflow.com/a/10374456

groupedCandidateNumbers
# Out:
#                                                  count
# mostRelevantUni mostRelevantField highestDegree
# BU              Biology           Masters            1
#                                   PhD                1
#                 Business          Bachelors          1
#                                   Masters            2
#                 CS                Bachelors          2
# ...                                                ...
# UMass Amherst   Mechanical Eng    PhD                1
#                 Other             Bachelors          1
#                                   Masters            2
# UMass Boston    CS                Bachelors          1
# WPI             Other             Masters            1
#
# [189 rows x 1 columns]

# %%
groupedCandidateNumbers = groupedCandidateNumbers.rename(index={'ONE': 'one'})

# %%
# Reset index for fields

print(groupedCandidateNumbers.index)

groupedCandidateNumbers = groupedCandidateNumbers.reset_index(level=["mostRelevantField"])

print("\nNew index: \n")

print(set(groupedCandidateNumbers.index))
# Out:
# MultiIndex([(           'BU',        'Biology',   'Masters'),
#             (           'BU',        'Biology',       'PhD'),
#             (           'BU',       'Business', 'Bachelors'),
#             (           'BU',       'Business',   'Masters'),
#             (           'BU',             'CS', 'Bachelors'),
#             (           'BU',             'CS',   'Masters'),
#             (           'BU',   'Data Science',   'Masters'),
#             (           'BU', 'Mechanical Eng', 'Bachelors'),
#             (           'BU', 'Mechanical Eng',   'Masters'),
#             (           'BU',          'Other', 'Bachelors'),
#             ...
#             (        'Tufts',          'Other',   'Masters'),
#             (        'UConn',        'Biology',       'PhD'),
#             ('UMass Amherst', 'Electrical Eng',       'PhD'),
#             ('UMass Amherst',      'Materials',       'PhD'),
#             ('UMass Amherst', 'Mechanical Eng', 'Bachelors'),
#             ('UMass Amherst', 'Mechanical Eng',       'PhD'),
#             ('UMass Amherst',          'Other', 'Bachelors'),
#             ('UMass Amherst',          'Other',   'Masters'),
#             ( 'UMass Boston',             'CS', 'Bachelors'),
#             (          'WPI',          'Other',   'Masters')],
#            names=['mostRelevantUni', 'mostRelevantField', 'highestDegree'], length=189)
#
# New index:
#
# {('Dartmouth', 'PhD'), ('Tufts', 'Bachelors'), ('Harvard', 'Masters'), ('Boston College', 'MBA'), ('MIT', 'Masters'), ('NYU', 'PhD'), ('Other', 'Bachelors'), ('Northeastern', 'Masters'), ('BU', 'Bachelors'), ('UMass Amherst', 'Bachelors'), ('MIT', 'PhD'), ('Harvard', 'PhD'), ('Tufts', 'Masters'), ('UConn', 'PhD'), ('Hult Business', 'Bachelors'), ('Northeastern', 'PhD'), ('UMass Boston', 'Bachelors'), ('Other', 'Masters'), ('MIT', 'MBA'), ('BU', 'Masters'), ('UMass Amherst', 'Masters'), ('Boston College', 'Bachelors'), ('WPI', 'Masters'), ('Harvard', 'High school'), ('Other', 'PhD'), ('Dartmouth', 'Bachelors'), ('UMass Amherst', 'PhD'), ('Other', 'Other'), ('Tufts', 'MBA'), ('BU', 'PhD'), ('NYU', 'Bachelors'), ('Hult Business', 'Masters'), ('Other', 'MBA'), ('Boston College', 'Masters'), ('MIT', 'Bachelors'), ('Harvard', 'Bachelors'), ('Other', 'High school'), ('Dartmouth', 'Masters'), ('Boston College', 'PhD'), ('Brandeis', 'PhD'), ('NYU', 'Masters'), ('Northeastern', 'Bachelors'), ('Hult Business', 'MBA')}

# %%
print(groupedCandidateNumbers.index)
# Out:
# MultiIndex([(           'BU',   'Masters'),
#             (           'BU',       'PhD'),
#             (           'BU', 'Bachelors'),
#             (           'BU',   'Masters'),
#             (           'BU', 'Bachelors'),
#             (           'BU',   'Masters'),
#             (           'BU',   'Masters'),
#             (           'BU', 'Bachelors'),
#             (           'BU',   'Masters'),
#             (           'BU', 'Bachelors'),
#             ...
#             (        'Tufts',   'Masters'),
#             (        'UConn',       'PhD'),
#             ('UMass Amherst',       'PhD'),
#             ('UMass Amherst',       'PhD'),
#             ('UMass Amherst', 'Bachelors'),
#             ('UMass Amherst',       'PhD'),
#             ('UMass Amherst', 'Bachelors'),
#             ('UMass Amherst',   'Masters'),
#             ( 'UMass Boston', 'Bachelors'),
#             (          'WPI',   'Masters')],
#            names=['mostRelevantUni', 'highestDegree'], length=189)

# %%
groupedCandidateNumbers[groupedCandidateNumbers.index.duplicated()]
# Out:
#                               mostRelevantField  count
# mostRelevantUni highestDegree
# BU              Masters                Business      2
#                 Bachelors                    CS      2
#                 Masters                      CS      3
#                 Masters            Data Science      2
#                 Bachelors        Mechanical Eng      4
# ...                                         ...    ...
# Tufts           Bachelors                 Other      3
#                 Masters                   Other      3
# UMass Amherst   PhD                   Materials      1
#                 PhD              Mechanical Eng      1
#                 Bachelors                 Other      1
#
# [146 rows x 2 columns]

# %%
# Change uni name order

#Wellesley left out 
new_index = ["MIT", "Harvard", "NYU", "Hult Business",
             "Northeastern", "BU", "Tufts", "Dartmouth",
             "Brandeis", "Boston College", 
             "UMass Amherst", "UMass Boston", "WPI", "UConn", "Other"
            ]

new_index.reverse()

# %%
# Show the difference between sets
list(set(new_index) - set(groupedCandidateNumbers.index))
# Out:
# ['UMass Amherst',
#  'UConn',
#  'NYU',
#  'Harvard',
#  'UMass Boston',
#  'WPI',
#  'BU',
#  'Tufts',
#  'Other',
#  'MIT',
#  'Northeastern',
#  'Hult Business',
#  'Boston College',
#  'Dartmouth',
#  'Brandeis']

# %%
#groupedCandidateNumbers2 = groupedCandidateNumbers.reindex(new_index)
groupedCandidateNumbersRelisted = groupedCandidateNumbers.loc[new_index]

groupedCandidateNumbersRelisted

# Export as JSON
#groupedCandidateNumbers2.to_json("New_Groups.json", orient='records')
# Out:
#                               mostRelevantField  count
# mostRelevantUni highestDegree
# Other           Other                        AI      1
#                 PhD                          AI      1
#                 Bachelors                  Aero      1
#                 PhD                        Aero      1
#                 Bachelors               Biology     18
# ...                                         ...    ...
# MIT             Masters                   Other     30
#                 PhD                       Other     15
#                 Bachelors               Physics      8
#                 Masters                 Physics      1
#                 PhD                     Physics      5
#
# [189 rows x 2 columns]

# %%
print(set(groupedCandidateNumbersRelisted.index))
# Out:
# {('Dartmouth', 'PhD'), ('Tufts', 'Bachelors'), ('Harvard', 'Masters'), ('Boston College', 'MBA'), ('NYU', 'PhD'), ('MIT', 'Masters'), ('Other', 'Bachelors'), ('Northeastern', 'Masters'), ('UMass Amherst', 'Bachelors'), ('BU', 'Bachelors'), ('MIT', 'PhD'), ('Harvard', 'PhD'), ('Tufts', 'Masters'), ('UConn', 'PhD'), ('Hult Business', 'Bachelors'), ('Northeastern', 'PhD'), ('UMass Boston', 'Bachelors'), ('Other', 'Masters'), ('MIT', 'MBA'), ('UMass Amherst', 'Masters'), ('BU', 'Masters'), ('Boston College', 'Bachelors'), ('Harvard', 'High school'), ('Other', 'PhD'), ('Dartmouth', 'Bachelors'), ('UMass Amherst', 'PhD'), ('Other', 'Other'), ('Tufts', 'MBA'), ('BU', 'PhD'), ('NYU', 'Bachelors'), ('Hult Business', 'Masters'), ('Other', 'MBA'), ('Boston College', 'Masters'), ('Northeastern', 'Bachelors'), ('MIT', 'Bachelors'), ('Harvard', 'Bachelors'), ('Other', 'High school'), ('Dartmouth', 'Masters'), ('Boston College', 'PhD'), ('Brandeis', 'PhD'), ('NYU', 'Masters'), ('WPI', 'Masters'), ('Hult Business', 'MBA')}

# %%
# Reset index
groupedCandidateNumbersRelisted = groupedCandidateNumbersRelisted.reset_index()

groupedCandidateNumbersRelisted
# Out:
#     mostRelevantUni highestDegree mostRelevantField  count
# 0             Other         Other                AI      1
# 1             Other           PhD                AI      1
# 2             Other     Bachelors              Aero      1
# 3             Other           PhD              Aero      1
# 4             Other     Bachelors           Biology     18
# ..              ...           ...               ...    ...
# 184             MIT       Masters             Other     30
# 185             MIT           PhD             Other     15
# 186             MIT     Bachelors           Physics      8
# 187             MIT       Masters           Physics      1
# 188             MIT           PhD           Physics      5
#
# [189 rows x 4 columns]

# %%
groupedCandidateNumbersRelisted.rename(columns={
    'mostRelevantUni': 'University',
    'mostRelevantField': 'Major',
    'highestDegree': 'Highest degree',
    'count': 'Number of Records'}, 
    inplace=True)

# %% [markdown]
# ### Remove empty university labels "None"

# %%
# # Remove None university
# # This is not necessary

listCurrentYear = groupedCandidateNumbersRelisted #[groupedCandidateNumbersRelisted['University'] != 'Other']

# %%
listCurrentYear
# Out:
#     University Highest degree    Major  Number of Records
# 0        Other          Other       AI                  1
# 1        Other            PhD       AI                  1
# 2        Other      Bachelors     Aero                  1
# 3        Other            PhD     Aero                  1
# 4        Other      Bachelors  Biology                 18
# ..         ...            ...      ...                ...
# 184        MIT        Masters    Other                 30
# 185        MIT            PhD    Other                 15
# 186        MIT      Bachelors  Physics                  8
# 187        MIT        Masters  Physics                  1
# 188        MIT            PhD  Physics                  5
#
# [189 rows x 4 columns]

# %% [markdown]
# # Year

# %%
# Add year information as a new column
# Applied to all rows
listCurrentYear['Year'] = '2022'

# %%
listCurrentYear.keys()
# Out:
# Index(['University', 'Highest degree', 'Major', 'Number of Records', 'Year'], dtype='object')

# %%
pd.set_option('display.min_rows', 1000)


listCurrentYear
# Out:
#     University Highest degree           Major  Number of Records  Year
# 0        Other          Other              AI                  1  2022
# 1        Other            PhD              AI                  1  2022
# 2        Other      Bachelors            Aero                  1  2022
# 3        Other            PhD            Aero                  1  2022
# 4        Other      Bachelors         Biology                 18  2022
# 5        Other        Masters         Biology                 19  2022
# 6        Other          Other         Biology                 34  2022
# 7        Other            PhD         Biology                 21  2022
# 8        Other      Bachelors        Business                 12  2022
# 9        Other            MBA        Business                  3  2022
# 10       Other        Masters        Business                 47  2022
# 11       Other          Other        Business                 44  2022
# 12       Other      Bachelors              CS                 35  2022
# 13       Other        Masters              CS                 17  2022
# 14       Other          Other              CS                 26  2022
# 15       Other            PhD              CS                  3  2022
# 16       Other      Bachelors       Chemistry                  6  2022
# 17       Other        Masters       Chemistry                  4  2022
# 18       Other          Other       Chemistry                  3  2022
# 19       Other            PhD       Chemistry                  4  2022
# 20       Other      Bachelors    Data Science                  1  2022
# 21       Other      Bachelors  Electrical Eng                  6  2022
# 22       Other        Masters  Electrical Eng                  9  2022
# 23       Other          Other  Electrical Eng                 10  2022
# 24       Other            PhD  Electrical Eng                  3  2022
# 25       Other      Bachelors         Finance                 21  2022
# 26       Other        Masters         Finance                 18  2022
# 27       Other          Other         Finance                 18  2022
# 28       Other        Masters  Industrial Eng                  1  2022
# 29       Other          Other  Industrial Eng                  2  2022
# ..         ...            ...             ...                ...   ...
# 159        MIT      Bachelors        Business                  1  2022
# 160        MIT            MBA        Business                  2  2022
# 161        MIT        Masters        Business                 34  2022
# 162        MIT            PhD        Business                  4  2022
# 163        MIT      Bachelors              CS                 53  2022
# 164        MIT        Masters              CS                 12  2022
# 165        MIT            PhD              CS                 13  2022
# 166        MIT      Bachelors       Chemistry                  4  2022
# 167        MIT        Masters       Chemistry                  5  2022
# 168        MIT            PhD       Chemistry                  4  2022
# 169        MIT        Masters       Civil Eng                  1  2022
# 170        MIT      Bachelors    Data Science                  1  2022
# 171        MIT      Bachelors  Electrical Eng                  7  2022
# 172        MIT            PhD  Electrical Eng                  6  2022
# 173        MIT      Bachelors         Finance                  3  2022
# 174        MIT        Masters         Finance                  8  2022
# 175        MIT            PhD         Finance                  1  2022
# 176        MIT      Bachelors       Materials                  4  2022
# 177        MIT        Masters       Materials                  2  2022
# 178        MIT            PhD       Materials                  3  2022
# 179        MIT      Bachelors  Mechanical Eng                 23  2022
# 180        MIT        Masters  Mechanical Eng                 10  2022
# 181        MIT            PhD  Mechanical Eng                  7  2022
# 182        MIT      Bachelors           Other                 25  2022
# 183        MIT            MBA           Other                 21  2022
# 184        MIT        Masters           Other                 30  2022
# 185        MIT            PhD           Other                 15  2022
# 186        MIT      Bachelors         Physics                  8  2022
# 187        MIT        Masters         Physics                  1  2022
# 188        MIT            PhD         Physics                  5  2022
#
# [189 rows x 5 columns]

# %% [markdown]
# # Export as CSV and JSON

# %%
# Export as CSV
df.to_csv("FP_candidates_2024.csv")

# %%
# Export as JSON
listCurrentYear.to_json("FP_Groups_2022.json", orient='records')

# %%
print('Done! :)')
# Out:
# Done! :)
